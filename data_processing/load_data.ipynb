# %%
# %pip install pyodbc
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd, urllib
from sqlalchemy import create_engine

df = pd.read_csv("/Users/sivhoung/Fraud_detection/historical_data/part-00000-afbc1c86-0307-4cb4-96a5-8db1604ed007-c000.csv")

params = urllib.parse.quote_plus(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=paysim-db.c78a2mamcvtr.ap-southeast-2.rds.amazonaws.com,1433;"
    "DATABASE=FraudDetectionDB;"
    "UID=admin;"        # the admin login you set when creating the RDS instance
    "PWD=GCTFFh6bOvcZMPSPmE2k;"
    "Encrypt=yes;"
    "TrustServerCertificate=yes;"      # see note below
)
engine = create_engine(
    f"mssql+pyodbc:///?odbc_connect={params}",
    fast_executemany=True
)

df.to_sql("historical_transactions", engine, schema="dbo",
          if_exists="append", index=False, chunksize=10000)
# Out:
# -510
